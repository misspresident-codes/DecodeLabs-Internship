# %% [markdown]
# <a href="https://colab.research.google.com/github/misspresident-codes/DecodeLabs-Internship/blob/main/Project2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('/content/fraudTest.csv')

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2020-06-21 12:14:25  2291163933867244
# 1           1   2020-06-21 12:14:33  3573030041201292
# 2           2   2020-06-21 12:14:53  3598215285024754
# 3           3   2020-06-21 12:15:15  3591919803438423
# 4           4   2020-06-21 12:15:17  3526826139003047
#
#                                merchant        category    amt   first  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86    Jeff
# 1                  fraud_Sporer-Keebler   personal_care  29.84  Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley
# 3                     fraud_Haley Group        misc_pos  60.05   Brian
# 4                 fraud_Johnston-Casper          travel   3.19  Nathan
#
#        last gender                       street  ...      lat      long  \
# 0   Elliott      M            351 Darlene Green  ...  33.9659  -80.9355
# ...

# %%
df.tail()
# Out:
#         Unnamed: 0 trans_date_trans_time            cc_num  \
# 461261      461261   2020-12-11 05:15:30     4900628639996
# 461262      461262   2020-12-11 05:16:23      630469040731
# 461263      461263   2020-12-11 05:16:27  3596217206093829
# 461264      461264   2020-12-11 05:17:02  4610064888664703
# 461265      461265   2020-12-11 05:17:04  4302480582202074
#
#                                   merchant       category     amt     first  \
# 461261   fraud_Schoen, Kuphal and Nitzsche    grocery_pos   46.50   Michael
# 461262                 fraud_Koepp-Witting    grocery_pos  115.39  Meredith
# 461263                 fraud_Stracke-Lemke    grocery_pos  392.00      Sara
# 461264  fraud_Swift, Bradtke and Marquardt    grocery_net   86.68     Tammy
# 461265        fraud_Zieme, Bode and Dooley  gas_transport   48.76     David
#
#              last gender                       street  ...      lat      long  \
# ...

# %%
df.describe()
# Out:
#           Unnamed: 0        cc_num            amt            zip  \
# count  461266.000000  4.612660e+05  461266.000000  461266.000000
# mean   230632.500000  4.187036e+17      69.507467   48832.475346
# std    133156.168971  1.311093e+18     148.985642   26854.423705
# min         0.000000  6.041621e+10       1.000000    1257.000000
# 25%    115316.250000  1.800429e+14       9.630000   26237.000000
# 50%    230632.500000  3.521417e+15      47.340000   48174.000000
# 75%    345948.750000  4.642255e+15      83.090000   72011.000000
# max    461265.000000  4.992346e+18   19364.910000   99921.000000
#
#                  lat           long      city_pop     unix_time  \
# count  461266.000000  461266.000000  4.612660e+05  4.612660e+05
# mean       38.541785     -90.227806  8.827129e+04  1.379255e+09
# std         5.060941      13.722138  3.002937e+05  4.539538e+06
# min        20.027100    -165.672300  2.300000e+01  1.371817e+09
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 461266 entries, 0 to 461265
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             461266 non-null  int64
#  1   trans_date_trans_time  461266 non-null  object
#  2   cc_num                 461266 non-null  int64
#  3   merchant               461266 non-null  object
#  4   category               461266 non-null  object
#  5   amt                    461266 non-null  float64
#  6   first                  461266 non-null  object
#  7   last                   461266 non-null  object
#  8   gender                 461266 non-null  object
#  9   street                 461266 non-null  object
#  10  city                   461266 non-null  object
#  11  state                  461266 non-null  object
#  12  zip                    461266 non-null  int64
#  13  lat                    461266 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0               0
# trans_date_trans_time    0
# cc_num                   0
# merchant                 0
# category                 0
# amt                      0
# first                    0
# last                     0
# gender                   0
# street                   0
# city                     0
# state                    0
# zip                      0
# lat                      0
# long                     0
# city_pop                 0
# job                      0
# dob                      0
# trans_num                0
# unix_time                0
# merch_lat                0
# merch_long               0
# is_fraud                 1
# dtype: int64
